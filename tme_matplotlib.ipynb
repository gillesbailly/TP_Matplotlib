# %% [markdown]
# # TME Matplotlib pour l'UE IHM
# exécuter le code à chaque puce

# %%
# Imports
import numpy as np
import matplotlib.pyplot as plt

# Cos and Sin
X = np.linspace(-np.pi, np.pi, 256,endpoint=True)
C = np.cos(X)
S = np.sin(X)

# %% [markdown]
# ## Étape 1
# <strong>Tester les basiques de matplotlib</strong>
# <ul>
#     <li>Afficher les fonctions cos (C) and sin (S) à l'aide de fonction <strong>plot</strong> sur la même figure (2 lignes) </li>
#     <li>Changer la largeur, le style et la couleur des lignes à l'aide des attributs <strong>linewidth</strong>,  <strong>linestyle</strong> et <strong>color</strong></li>
#     <li>Ajouter titre, labels sur les axes à l'aide des fonctions <strong>plt.title()</strong>, <strong>plt.xlabel()</strong>, <strong>plt.ylabel()</strong> </li>
#         <li>Ajouter une légende. Pour cela, il faut ajouter un label à chacun de vos <strong>plots</strong> à l'aide de l'attribut <strong>label</strong>. Créer ensuite une légende à l'aide de  <strong>plt.legend()</strong>. Vous pouvez changer sa position à l'aide de l'attribut <strong>loc</strong>  labels sur les axes à l'aide des fonctions <strong>plt.title()</strong>, <strong>plt.xlabel()</strong>, <strong>plt.ylabel()</strong> </li>
#
# </ul>
# <p style="color:#FF0000"> Pour toutes les questions suivantes, n'oubliez pas d'avoir toutes informations nécessaires pour comprendre la figure, c'est à dire titre, label sur les axes, unités si pertinent, légende si pertinent.</p>

# %%
# Create a new figure of size 8x6 points, using 100 dots per inch
plt.figure(figsize=(8,6), dpi=100)

# Create a new subplot from a grid of 1x1
plt.subplot(111)

X = np.linspace(-np.pi, np.pi, 256,endpoint=True)
C = np.cos(X)
S = np.sin(X)

#Plot cosine
plt.plot(X,C)

# Show result on screen
plt.show()

# %% [markdown]
# #Étape 2 Ajouter des annotations
# <ul>
#     <li> Copier / Coller le code précédent</li>
#     <li> Ajouter une annotation à l'intersection des deux courbes. Pour cela, vous utiliserez la fonction <strong>plt.annotate()</strong>. Vous afficherez une flèche à l'aide de l'attribut <strong></strong> </li>
#
# </ul>

# %%
# Create a new figure of size 8x6 points, using 100 dots per inch
plt.figure(figsize=(8,6), dpi=100)

# Create a new subplot from a grid of 1x1
plt.subplot(111)



#Plot cosine
plt.plot(X,C, linewidth = 3, color = "blue", linestyle = "-.", label ="cos" )
plt.plot(X,S, linewidth = 1, color = "red" , linestyle = "--", label = "sin" )
t = 2
#plt.scatter(t, np.cos(t))
plt.title("cos and sin")
plt.xlabel("x"), plt.ylabel("y")
#plt.annotate(r'$\cos(2)$',
#             xy=(t, np.cos(t)),  xycoords='data',
#             xytext=(-90, -50), textcoords='offset points', fontsize=16,
#             arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))
plt.annotate(r'$\cos(2)$',
             xy=(t, np.cos(t)),  xycoords='data',
             xytext=(-90, -50), textcoords='offset points', fontsize=16,
             arrowprops=dict(arrowstyle="->")) 
#             connectionstyle="arc3,rad=.2")


plt.legend()

# Plot cosine using blue color with a continuous line of width 1 (pixels)
#plt.plot(X, C, color="blue", linewidth=1.0, linestyle="-")

# Plot sine using green color with a continuous line of width 1 (pixels)
#plt.plot(X, S, color="green", linewidth=1.0, linestyle="-")

# Set x limits
#plt.xlim(-4.0,4.0)

# Set x ticks
#plt.xticks(np.linspace(-4,4,9,endpoint=True))

# Set y limits
#plt.ylim(-1.0,1.0)

# Set y ticks
#plt.yticks(np.linspace(-1,1,5,endpoint=True))

# Save figure using 72 dots per inch
# savefig("../figures/exercice_2.png",dpi=72)

# Show result on screen
plt.show()

# %% [markdown]
# # Animation avec Matplotlib
#
# En théorie, l'animation devrait fonctionner. En pratique, sous jupyter notebook, ce n'est pas le cas et il faut transformer l'animation en une vidéo.
# Solution 1: copier / coller ce code dans un fichier python et exécuter le.
# Solution 2:
# <ul>
#     <li>assurez vous que importez bien HTML</li>
#     <li>assurez vous que ffmpeg est installé. Avec Anacoda, tapez <strong>conda install -c conda-forge ffmpeg</strong></li>
#     <li>remplacer <strong>plt.show</strong> par <strong>HTML(animation.to_html5_video())</strong></li>
# </ul>

# %%
from matplotlib.animation import FuncAnimation

# %%
# animation.save('rain.gif', writer='imagemagick', fps=30, dpi=40)

# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import animation, rc
from IPython.display import HTML

# No toolbar
matplotlib.rcParams['toolbar'] = 'None'

# New figure with white background
fig = plt.figure(figsize=(6,6), facecolor='white')

# New axis over the whole figureand a 1:1 aspect ratio
# ax = fig.add_axes([0,0,1,1], frameon=False, aspect=1)
ax = fig.add_axes([0.005,0.005,0.990,0.990], frameon=True, aspect=1)

# Number of ring
n = 50
size_min = 50
size_max = 50*50
          
# Ring position 
P = np.random.uniform(0,1,(n,2))

# Ring colors
C = np.ones((n,4)) * (0,0,0,1)

# Alpha color channel goes from 0 (transparent) to 1 (opaque)
C[:,3] = np.linspace(0,1,n)

# Ring sizes
S = np.linspace(size_min, size_max, n)

# Scatter plot
scat = ax.scatter(P[:,0], P[:,1], s=S, lw = 0.5,
                  edgecolors = C, facecolors='None')

# Ensure limits are [0,1] and remove ticks
ax.set_xlim(0,1), ax.set_xticks([])
ax.set_ylim(0,1), ax.set_yticks([])


def update(frame):
    global P, C, S

    # Every ring is made more transparent
    C[:,3] = np.maximum(0, C[:,3] - 1.0/n)

    # Each ring is made larger
    S += (size_max - size_min) / n

    # Reset ring specific ring (relative to frame number)
    i = frame % 50
    P[i] = np.random.uniform(0,1,2)
    S[i] = size_min
    C[i,3] = 1

    # Update scatter object
    scat.set_edgecolors(C)
    scat.set_sizes(S)
    scat.set_offsets(P)
    return scat,

animation = FuncAnimation(fig, update, interval=10)
# animation.save('../figures/rain.gif', writer='imagemagick', fps=30, dpi=72)
HTML(animation.to_html5_video())
#plt.show()
# Out:
# MovieWriter stderr:
# dyld: Library not loaded: @rpath/libopenh264.5.dylib
#   Referenced from: /Users/bailly/anaconda3/lib/libavcodec.58.54.100.dylib
#   Reason: image not found
# ---------------------------------------------------------------------------
# BrokenPipeError                           Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     229         try:
# --> 230             yield self
#     231         finally:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1151                             frame_number += 1
# -> 1152                     writer.grab_frame(**savefig_kwargs)
#    1153
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in grab_frame(self, **savefig_kwargs)
#     384         self.fig.savefig(self._frame_sink(), format=self.frame_format,
# --> 385                          dpi=self.dpi, **savefig_kwargs)
#     386
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2202
# -> 2203         self.canvas.print_figure(fname, **kwargs)
#    2204
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2125                     bbox_inches_restore=_bbox_inches_restore,
# -> 2126                     **kwargs)
#    2127             finally:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in print_raw(self, filename_or_obj, *args, **kwargs)
#     449         with cbook.open_file_cm(filename_or_obj, "wb") as fh:
# --> 450             fh.write(renderer.buffer_rgba())
#     451
#
# BrokenPipeError: [Errno 32] Broken pipe
#
# During handling of the above exception, another exception occurred:
#
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-35-e86acc11b56b> in <module>
#      63 animation = FuncAnimation(fig, update, interval=10)
#      64 # animation.save('../figures/rain.gif', writer='imagemagick', fps=30, dpi=72)
# ---> 65 HTML(animation.to_html5_video())
#      66 #plt.show()
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in to_html5_video(self, embed_limit)
#    1330                                 bitrate=rcParams['animation.bitrate'],
#    1331                                 fps=1000. / self._interval)
# -> 1332                 self.save(str(path), writer=writer)
#    1333                 # Now open and base64 encode.
#    1334                 vid64 = base64.encodebytes(path.read_bytes())
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1150                             progress_callback(frame_number, total_frames)
#    1151                             frame_number += 1
# -> 1152                     writer.grab_frame(**savefig_kwargs)
#    1153
#    1154         # Reconnect signal for first draw if necessary
#
# ~/anaconda3/lib/python3.7/contextlib.py in __exit__(self, type, value, traceback)
#     128                 value = type()
#     129             try:
# --> 130                 self.gen.throw(type, value, traceback)
#     131             except StopIteration as exc:
#     132                 # Suppress StopIteration *unless* it's the same exception that
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     230             yield self
#     231         finally:
# --> 232             self.finish()
#     233
#     234
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in finish(self)
#     366     def finish(self):
#     367         '''Finish any processing for writing the movie.'''
# --> 368         self.cleanup()
#     369
#     370     def grab_frame(self, **savefig_kwargs):
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in cleanup(self)
#     410         if self._proc.returncode:
#     411             raise subprocess.CalledProcessError(
# --> 412                 self._proc.returncode, self._proc.args, out, err)
#     413
#     414     @classmethod
#
# CalledProcessError: Command '['ffmpeg', '-f', 'rawvideo', '-vcodec', 'rawvideo', '-s', '432x432', '-pix_fmt', 'rgba', '-r', '100.0', '-loglevel', 'error', '-i', 'pipe:', '-vcodec', 'h264', '-pix_fmt', 'yuv420p', '-y', '/var/folders/m_/jsw8fptd6633yr2n6wz462zw0000gn/T/tmpifzih4ps/temp.m4v']' died with <Signals.SIGABRT: 6>.
